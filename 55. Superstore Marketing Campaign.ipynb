# %% [markdown]
# # Superstore Marketing Campaign

# %% [markdown]
# ## Getting dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/proj55/superstore_data.csv")
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
df.head().T
# Out:
#                               0           1           2           3  \
# Id                         1826           1       10476        1386
# Year_Birth                 1970        1961        1958        1967
# Education            Graduation  Graduation  Graduation  Graduation
# Marital_Status         Divorced      Single     Married    Together
# Income                  84835.0     57091.0     67267.0     32474.0
# Kidhome                       0           0           0           1
# Teenhome                      0           0           1           1
# Dt_Customer           6/16/2014   6/15/2014   5/13/2014   11/5/2014
# Recency                       0           0           0           0
# MntWines                    189         464         134          10
# MntFruits                   104           5          11           0
# MntMeatProducts             379          64          59           1
# MntFishProducts             111           7          15           0
# ...

# %% [markdown]
# ## Cleaning Dataset

# %%
df.isna().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
df["Income"].fillna(np.mean(df["Income"]), inplace=True)

# %%
df.isna().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %% [markdown]
# ## Exploring Dataset

# %%
df.head().T
# Out:
#                               0           1           2           3  \
# Id                         1826           1       10476        1386
# Year_Birth                 1970        1961        1958        1967
# Education            Graduation  Graduation  Graduation  Graduation
# Marital_Status         Divorced      Single     Married    Together
# Income                  84835.0     57091.0     67267.0     32474.0
# Kidhome                       0           0           0           1
# Teenhome                      0           0           1           1
# Dt_Customer           6/16/2014   6/15/2014   5/13/2014   11/5/2014
# Recency                       0           0           0           0
# MntWines                    189         464         134          10
# MntFruits                   104           5          11           0
# MntMeatProducts             379          64          59           1
# MntFishProducts             111           7          15           0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df["Complain"].value_counts().values
# Out:
# array([2219,   21])

# %%
sns.barplot(x=[0, 1], y=df["Complain"].value_counts().values, )
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="Income", y="NumStorePurchases", data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='NumStorePurchases'>

# %% [markdown]
# ## Pre-Processing Dataset

# %%
df.head().T
# Out:
#                               0           1           2           3  \
# Id                         1826           1       10476        1386
# Year_Birth                 1970        1961        1958        1967
# Education            Graduation  Graduation  Graduation  Graduation
# Marital_Status         Divorced      Single     Married    Together
# Income                  84835.0     57091.0     67267.0     32474.0
# Kidhome                       0           0           0           1
# Teenhome                      0           0           1           1
# Dt_Customer           6/16/2014   6/15/2014   5/13/2014   11/5/2014
# Recency                       0           0           0           0
# MntWines                    189         464         134          10
# MntFruits                   104           5          11           0
# MntMeatProducts             379          64          59           1
# MntFishProducts             111           7          15           0
# ...

# %%
df.drop("Id", axis=1, inplace=True)

from sklearn.preprocessing import LabelEncoder

df.drop("Dt_Customer", axis=1, inplace=True)

for column in df.keys():
    if pd.api.types.is_object_dtype(df[column]):
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])
        print("-"*20)
        print(column)
        print(le.classes_)
        print("-"*20)
    else:
        pass

X = df.drop("Complain", axis=1)
y = df["Complain"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# --------------------
# Education
# ['2n Cycle' 'Basic' 'Graduation' 'Master' 'PhD']
# --------------------
# --------------------
# Marital_Status
# ['Absurd' 'Alone' 'Divorced' 'Married' 'Single' 'Together' 'Widow' 'YOLO']
# --------------------

# %% [markdown]
# ## Training Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
rfclf = RandomForestClassifier()
rfclf.fit(X_train, y_train)
rfclf.score(X_test, y_test)
# Out:
# 0.9888392857142857

# %%
kclf = KNeighborsClassifier().fit(X_train, y_train)
kclf.score(X_test, y_test)
# Out:
# 0.9866071428571429

# %%
svclf = SVC().fit(X_train, y_train)
svclf.score(X_test, y_test)
# Out:
# 0.9866071428571429

# %%
xgbclf = XGBClassifier()
xgbclf.fit(X_train.values, y_train.values)
xgbclf.score(X_test, y_test)
# Out:
# 0.9888392857142857
