# %% [markdown]
# # Apples or Tomatoes Prediction

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_set = train_gen.flow_from_directory(
    "data/proj23/train/",
    target_size=(64, 64),
    batch_size=32,
    class_mode="binary"
)
# Out:
# Found 294 images belonging to 2 classes.

# %%
test_gen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_set = test_gen.flow_from_directory(
    "data/proj23/test/",
    target_size=(64, 64),
    batch_size=32,
    class_mode="binary"
)
# Out:
# Found 97 images belonging to 2 classes.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters=32, input_shape=(64, 64, 3), kernel_size=3, activation='relu'))
model.add(keras.layers.MaxPool2D(pool_size=2, strides=2))
model.add(keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu' ))
model.add(keras.layers.MaxPooling2D(pool_size=2, strides=2))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units=128, activation='relu'))
model.add(keras.layers.Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=train_set, validation_data=test_set, epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.7839 - accuracy: 0.5068 - val_loss: 0.6838 - val_accuracy: 0.6289
# Epoch 2/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.6845 - accuracy: 0.5578 - val_loss: 0.6703 - val_accuracy: 0.6186
# Epoch 3/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.6452 - accuracy: 0.6463 - val_loss: 0.6102 - val_accuracy: 0.6392
# Epoch 4/100
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6203 - accuracy: 0.6429 - val_loss: 0.6298 - val_accuracy: 0.5979
# Epoch 5/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.6053 - accuracy: 0.6497 - val_loss: 0.6269 - val_accuracy: 0.6495
# Epoch 6/100
# 10/10 [==============================] - 2s 145ms/step - loss: 0.5693 - accuracy: 0.6905 - val_loss: 0.6044 - val_accuracy: 0.6701
# Epoch 7/100
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img("data/proj23/test/tomatoes/img_p1_107.jpeg", target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict(test_image)
print(train_set.class_indices)
print(result)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# {'apples': 0, 'tomatoes': 1}
# [[1.]]
