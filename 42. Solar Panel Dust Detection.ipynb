# %%
# %%bash
#
# pip install -q kaggle
# mkdir -p ~/.kaggle
# cp drive/MyDrive/kaggle.json ~/.kaggle/
# chmod 600 /root/.kaggle/kaggle.json
# kaggle datasets download -d hemanthsai7/solar-panel-dust-detection
# Out:
# Downloading solar-panel-dust-detection.zip to /content
# 100%|██████████| 1.18G/1.18G [01:02<00:00, 20.3MB/s]

# %%
# !unzip solar-panel-dust-detection.zip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras

# %%
data_gen = ImageDataGenerator(
    zoom_range=0.2,
    shear_range=0.2,
    rescale=1./255,
    validation_split=0.2,
    horizontal_flip=True
)

# %%
train_set = data_gen.flow_from_directory(
    "Detect_solar_dust",
    target_size=(224, 224),
    class_mode='binary',
    seed=123,
    subset='training',
    batch_size=32
)

valid_set = data_gen.flow_from_directory(
    "Detect_solar_dust",
    target_size=(224, 224),
    class_mode='binary',
    seed=123,
    subset='validation',
    batch_size=32
)
# Out:
# Found 2051 images belonging to 2 classes.
# Found 511 images belonging to 2 classes.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters=32, kernel_size=3, input_shape=(224, 224, 3), activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=2))
model.add(keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=3))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(420, activation='relu'))
model.add(keras.layers.Dense(120, activation='relu')) 
model.add(keras.layers.Dense(60, activation='relu'))
model.add(keras.layers.Dense(2, activation='sigmoid'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=train_set, epochs=20, batch_size=32, validation_data=valid_set)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  8/65 [==>...........................] - ETA: 1:06 - loss: 0.9435 - accuracy: 0.6016
# /usr/local/lib/python3.8/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 65/65 [==============================] - 118s 2s/step - loss: 0.6797 - accuracy: 0.6143 - val_loss: 0.5912 - val_accuracy: 0.6751
# Epoch 2/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.5991 - accuracy: 0.6865 - val_loss: 0.6729 - val_accuracy: 0.6517
# Epoch 3/20
# 65/65 [==============================] - 105s 2s/step - loss: 0.5822 - accuracy: 0.7060 - val_loss: 0.5684 - val_accuracy: 0.7280
# Epoch 4/20
# 65/65 [==============================] - 104s 2s/step - loss: 0.5462 - accuracy: 0.7177 - val_loss: 0.5402 - val_accuracy: 0.7476
# Epoch 5/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.5339 - accuracy: 0.7411 - val_loss: 0.5327 - val_accuracy: 0.7652
# Epoch 6/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.4967 - accuracy: 0.7655 - val_loss: 0.5506 - val_accuracy: 0.7123
# Epoch 7/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.4820 - accuracy: 0.7786 - val_loss: 0.5701 - val_accuracy: 0.7319
# Epoch 8/20
# 65/65 [==============================] - 107s 2s/step - loss: 0.4851 - accuracy: 0.7650 - val_loss: 0.5578 - val_accuracy: 0.7339
# Epoch 9/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.4795 - accuracy: 0.7708 - val_loss: 0.5499 - val_accuracy: 0.7299
# Epoch 10/20
# 65/65 [==============================] - 107s 2s/step - loss: 0.4628 - accuracy: 0.7816 - val_loss: 0.5515 - val_accuracy: 0.7515
# Epoch 11/20
# 65/65 [==============================] - 105s 2s/step - loss: 0.4476 - accuracy: 0.7855 - val_loss: 0.5834 - val_accuracy: 0.7319
# Epoch 12/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.4256 - accuracy: 0.8025 - val_loss: 0.6011 - val_accuracy: 0.7476
# Epoch 13/20
# 65/65 [==============================] - 105s 2s/step - loss: 0.3930 - accuracy: 0.8196 - val_loss: 0.5354 - val_accuracy: 0.7710
# Epoch 14/20
# 65/65 [==============================] - 105s 2s/step - loss: 0.3775 - accuracy: 0.8269 - val_loss: 0.6659 - val_accuracy: 0.7476
# Epoch 15/20
# 65/65 [==============================] - 107s 2s/step - loss: 0.3470 - accuracy: 0.8411 - val_loss: 0.6087 - val_accuracy: 0.7828
# Epoch 16/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.3209 - accuracy: 0.8571 - val_loss: 0.6330 - val_accuracy: 0.7554
# Epoch 17/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.2937 - accuracy: 0.8679 - val_loss: 0.6782 - val_accuracy: 0.7671
# Epoch 18/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.2665 - accuracy: 0.8927 - val_loss: 0.7410 - val_accuracy: 0.7828
# Epoch 19/20
# 65/65 [==============================] - 106s 2s/step - loss: 0.2594 - accuracy: 0.8922 - val_loss: 0.6843 - val_accuracy: 0.7593
# Epoch 20/20
# 65/65 [==============================] - 103s 2s/step - loss: 0.2644 - accuracy: 0.8869 - val_loss: 0.7021 - val_accuracy: 0.7613
